# %%
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
csv_path = 'datasets/benchmark/benchmarK_Feb4_neg10k.csv'
df_neg = pd.read_csv(csv_path)
df_neg = df_neg.drop(df_neg.columns[[11, 12, 13, 14, 15,16]], axis=1)

# Set the column names
df_neg.columns = ['country','topic','subtopic','subsubtopic','url','assertion','pos1','pos2','pos2','neg','label']

# Display the first 5 rows of the DataFrame
df_neg.head()
# Out:
#        country     topic                              subtopic  \
# 0  Afghanistan   Culture                  Women in Afghanistan
# 1       Canada  Holidays                                Quebec
# 2      Albania   Culture              Summer Festival, Albania
# 3     Cambodia   Cuisine  Vietnamese cuisine#Regional cuisines
# 4  Afghanistan   Cuisine                               Cuisine
#
#                             subsubtopic  \
# 0                  Women in Afghanistan
# 1                                Quebec
# 2              Summer Festival, Albania
# 3  Vietnamese cuisine#Regional cuisines
# 4                        Afghan cuisine
#
#                                                  url  \
# 0  https://en.wikipedia.org/wiki/Women_in_Afghani...
# 1               https://en.wikipedia.org/wiki/Quebec
# 2    https://en.wikipedia.org/wiki/Dita_e_Ver%C3%ABs
# 3   https://en.wikipedia.org/wiki/Vietnamese_cuisine
# 4       https://en.wikipedia.org/wiki/Afghan_cuisine
#
# ...

# %%
# # Convert the DataFrame to a list of dictionaries
# df_neg_dict = df_neg.to_dict(orient='records')
# df_neg_dict

# %%
df_neg.iloc[5000].to_dict()
# Out:
# {'country': "Democratic People's Republic of Korea",
#  'topic': 'Holidays',
#  'subtopic': 'Kimchi',
#  'subsubtopic': 'Kimchi',
#  'url': 'https://en.wikipedia.org/wiki/Kimchi',
#  'assertion': '(0.5321469306945801, 0.38733339309692383, 0.47763189673423767, 0.06005270779132843, 0.026050535961985588, 0.010208248160779476, 0.03872329369187355)',
#  'na1': nan,
#  'na2': 'Kimchi (김치) is the accepted word in both North and South Korean standard languages.',
#  'na3': 'Kimchi (김치) is the accepted word for a traditional Korean side dish made of fermented vegetables, and this term is used in both North and South Korean standard languages.',
#  'na4': 'Kimchi (김치) is a modern invention and is not considered a traditional Korean side dish made of fermented vegetables.',
#  'label': False}

# %%
csv_path = 'datasets/benchmark/benchmarK_Feb4_pos10k.csv'
df_pos = pd.read_csv(csv_path)
df_pos = df_pos.drop(df_pos.columns[[11, 12, 13, 14, 15,16]], axis=1)

# Set the column names
df_pos.columns = ['country','topic','subtopic','subsubtopic','url','assertion','na1','na2','na3','na4','label']
# Display the first 5 rows of the DataFrame
df_pos.head()
# Out:
#        country    topic         subtopic             subsubtopic  \
# 0  Afghanistan  Culture          Culture  Culture of Afghanistan
# 1  Afghanistan  Culture          Culture  Culture of Afghanistan
# 2  Afghanistan  Culture          Culture  Culture of Afghanistan
# 3  Afghanistan  Culture          Culture  Culture of Afghanistan
# 4  Afghanistan  Culture  Afghan proverbs         Afghan proverbs
#
#                                                  url  \
# 0  https://en.wikipedia.org/wiki/Culture_of_Afgha...
# 1  https://en.wikipedia.org/wiki/Culture_of_Afgha...
# 2  https://en.wikipedia.org/wiki/Culture_of_Afgha...
# 3  https://en.wikipedia.org/wiki/Culture_of_Afgha...
# 4      https://en.wikipedia.org/wiki/Afghan_proverbs
#
#                                            assertion  \
# 0  (0.8879956603050232, 0.24886666238307953, 0.33...
# 1  (0.7940195798873901, 0.2013256847858429, 0.725...
# 2  (0.5817518830299377, 0.2714219391345978, 0.523...
# ...

# %%
df_pos.iloc[0].to_dict()
# Out:
# {'country': 'Afghanistan',
#  'topic': 'Culture',
#  'subtopic': 'Culture',
#  'subsubtopic': 'Culture of Afghanistan',
#  'url': 'https://en.wikipedia.org/wiki/Culture_of_Afghanistan',
#  'assertion': '(0.8879956603050232, 0.24886666238307953, 0.3330075740814209, 0.21089154481887817, 0.04608561471104622, 0.024061430245637894, 0.1370871514081955)',
#  'na1': 'The culture of Afghanistan has persisted for over three millennia, tracing record to at least the time of the Achaemenid Empire in 500 BCE, and encompasses the cultural diversity of the nation. Afghanistan\'s culture is historically strongly connected to nearby Persia, including the same religion, as the people of both countries have lived together for thousands of years. Its location at the crossroads of Central, South and Western Asia historically made it a hub of diversity, dubbed by one historian as the "roundabout of the ancient world". ',
# ...
